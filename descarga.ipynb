# %%
from urllib.request import urlretrieve

# %%
urlretrieve("https://github.com/seap-udea/meccel-clase-profesor/raw/refs/heads/main/CuadernoCeleste-VirialRelajacion.ipynb?authuser=1","Virial.ipynb")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 l = urlretrieve("https://github.com/seap-udea/meccel-clase-profesor/raw/refs/heads/main/CuadernoCeleste-VirialRelajacion.ipynb?authuser=1","Virial.ipynb")
#
# NameError: name 'urlretrieve' is not defined
